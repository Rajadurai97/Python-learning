# %% [markdown]
# # Python Data types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Numbers

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# # Modulo / "Mod" operator

# %%
7/4
# Out:
# 1.75

# %%
7%4 # % mod operator given a remaining value. we could fnid easily the odd or even value also
# Out:
# 3

# %%
15%5
# Out:
# 0

# %%
20%2
# Out:
# 0

# %%
2**3
# Out:
# 8

# %%
2+10*10+3
# Out:
# 105

# %%
(0.1+0.2-0.3)
# Out:
# 5.551115123125783e-17

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Vaiables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
My_dog = 2

My_dog = ['jack', 'ran']

# %%
print(My_dog) # here the last assigned variable is printed
# Out:
# ['jack', 'ran']

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a = a + a

# %%
a
# Out:
# 20

# %%
type(a)
# Out:
# int

# %%
a = 110.11

# %%
type(a)
# Out:
# float

# %%
My_income = 100
Tax_rate = 0.1
my_tax = My_income * Tax_rate

# %%
my_tax
# Out:
# 10.0

# %% [markdown]
# # String

# %% [markdown]
# Strings are sequences of characters, using the syntax of either single quotes or double quotes

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
'i don't do that'
# Out:
#   Cell In[84], line 1
#     'i don't do that'
#                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"i don't do that" # The reason why we use double quotes
# Out:
# "i don't do that"

# %% [markdown]
# The strings are ordered sequesnces it means we can using indexing and slicing to grab sub-sections of the stirng.
# Indexing notations uses [] notation after the string
# Indexing allows you to grab a single character from the string
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('hello world')
# Out:
# hello world

# %%
'hello world'
'hello world'
# Out:
# 'hello world'

# %%
print('hello world')
print('hello world')
# Out:
# hello world
# hello world

# %%
print('hello \n world') #\n new line
# Out:
# hello
#  world

# %%
print('hello \t world') #\t for tab space
# Out:
# hello 	 world

# %%
  len('hello') # here len used to find the length of the string
# Out:
# 5

# %%
len("i am") # Space also considered
# Out:
# 4
