# %% [markdown]
# # Booleans

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
1>2
# Out:
# False

# %%
1==1 #comparision operator
# Out:
# True

# %%
b = None # Nothing in the variable

# %%
b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Files

# %%
# %%writefile mylife.txt
# hello this is a text file
# hello first line
# hello second line
# Out:
# Overwriting mylife.txt

# %%
myfile = open('mylife.txt')

# %%
myfile.read() # /n indicates a new line
# Out:
# 'hello this is a text file\nhello first line \nhello second line\n'

# %%
pwd
# Out:
# 'C:\\Users\\rajad\\Documents\\Python'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0) # we need to read file again use the "seek"
# Out:
# 0

# %%
myfile.read()
# Out:
# 'hello this is a text file\nhello first line \nhello second line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines() # it giving a list [ ]
# Out:
# ['hello this is a text file\n', 'hello first line \n', 'hello second line\n']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
myfile.close()

# %%
with open('mylife.txt') as My_new_file:
    contents = My_new_file.read()

# %%
contents
# Out:
# 'hello this is a text file\nhello first line \nhello second line\n'

# %%
with open('mylife.txt',mode='r', ) as my:
    contents = my.read()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%writefile myfile.txt
# fisrt line
# second line
# third line
# Out:
# Overwriting myfile.txt

# %%
with open('myfile.txt', mode='r') as m1:
    contents = m1.read()
    print(contents)
# Out:
# fisrt line
# second line
# third line

# %%
with open('myfile.txt', mode='a') as m1:
    contents = m1.write('fourth line')
    print(contents)
# Out:
# 11

# %%
with open('myfile.txt', mode='r') as m1:
    contents = m1.read()
    print(contents)
# Out:
# fisrt line
# second line
# third line
# fourth line

# %%
with open('myfile1.txt', mode='w') as m1:
    m1.write('Hi')

# %%
with open('myfile1.txt', mode='r') as m1:
    contents = m1.read()
    print(contents)
# Out:
# Hi
