# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1<2>3
# Out:
# False

# %%
1<2 and 2<3 # both are equal'true'
# Out:
# True

# %%
1<2 and 2>3 # bothe are not equal 'false'
# Out:
# False

# %%
1<2 or 2<3 # both are equal'true'
# Out:
# True

# %%
1<2 or 2>3 # or operator we using sone one condition enoung 'true'
# Out:
# True

# %%
1>2 or 2>3
# Out:
# False

# %%
not 1==1
# Out:
# False

# %%
not 400>500
# Out:
# True
