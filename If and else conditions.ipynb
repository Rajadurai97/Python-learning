# %% [markdown]
# # Conditions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
if True:
    print("its true")
# Out:
# its true

# %%
if 3>2:
    print("its true")
# Out:
# its true

# %%
hungry = True
if hungry:
    print("its true")

# %%
hungry1 = False 
if hungry1:
    print("its true")
else:
    print("not")
# Out:
# not

# %%
loc = "salem"
if loc == 'chenni':
    print('AB')
else:
    print("BC")
# Out:
# BC

# %%
loc = "salem"
if loc == 'chenni':
    print('AB')
elif loc == "salem":
    print('s')
else:
    print("BC")
# Out:
# s
